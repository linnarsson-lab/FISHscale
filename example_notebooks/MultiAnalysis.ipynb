# %%
import sys
import pandas as pd
import os
sys.path.append('/Users/admin/OneDrive - KI.SE/Projects')

from FISHscale.utils import Dataset, MultiDataset

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load Directly from folder

# %%
# Include other_columns if you want your Dataset object to have .fov_num attrs or any other column
MD = MultiDataset('../../EEL/Cancer/processed_data/',gene_label='decoded_genes',other_columns=['fov_num'])

# %%
#Include a list of attrs from each Dataset object that you will like to be plotted as different categories
# at them moment all datasets will be loaded in memory and that will make plotting slower
MD.visualize()

# %% [markdown]
# # Load From individual PandasDataset objects

# %%
# In case you have preloaded Dataset objects
SL006 = Dataset('../../EEL/Cancer/AMEXP20210320_EEL_SL006/210413_17_10_56_AMEXP20210320_EEL_SL006_data_summary_simple_plotting.parquet',gene_label='decoded_genes',apply_offset=True)
SL005 = Dataset('../../EEL/Cancer/processed_data/210413_19_25_19_JJEXP20210323_EEL_SL005_data_summary_simple_plotting.parquet',gene_label='decoded_genes',apply_offset=True,x_offset=50000,unique_genes=SL006.unique_genes)
SL007 = Dataset('../../EEL/Cancer/processed_data/210414_19_55_34_JJEXP20210318_EEL_SL007_data_summary_simple_plotting.parquet',gene_label='decoded_genes',apply_offset=True,x_offset=100000,unique_genes=SL006.unique_genes)
SL003 = Dataset('../../EEL/Cancer/AMEXP20210315_EEL_SL003/20210329-AMEXP20210315_EEL_SL003.parquet',apply_offset=True,x_offset=150000,unique_genes=SL006.unique_genes)

MD = MultiDataset([SL006,SL003,SL005,SL007])

# %%
SL006 = Dataset('../../EEL/Cancer/AMEXP20210320_EEL_SL006/210413_17_10_56_AMEXP20210320_EEL_SL006_data_summary_simple_plotting.parquet',gene_label='decoded_genes',apply_offset=True,color_input='210413_17_10_56_AMEXP20210320_EEL_SL006_data_summary_simple_plotting_color_dictionary.pkl')
#SL006.visualize()

# %%
SL006.visualize()
# Out:
# Single Dataset
# ../../EEL/Cancer/AMEXP20210320_EEL_SL006/210413_17_10_56_AMEXP20210320_EEL_SL006_data_summary_simple_plotting.parquet
# Data Loaded
# a
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# decoded_genes decoded_genes
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# exec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ae98e74fed6e> in <module>
# ----> 1 SL006.visualize()
#
# ~/OneDrive - KI.SE/Projects/FISHscale/utils/dataset.py in visualize(self, columns, width, height, show_axis, color_dic)
#     243             print('QApplication instance already exists: %s' % str(App))
#     244
# --> 245         window = Window(self,columns,width,height,color_dic)
#     246         App.exec_()
#     247         App.quit()
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in __init__(self, dataset, columns, width, height, show_axis, color_dic)
#     103         else:
#     104             print('a')
# --> 105             self.vis.execute()
#     106
#     107
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# ...
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     194         self.visM.poll_events()
#     195         self.visM.update_renderer()
# --> 196         threading.Timer(0.1,self.execute()).start()
#     197
#     198
#
# ~/OneDrive - KI.SE/Projects/FISHscale/visualization/primitiveVis_open3dv2.py in execute(self)
#     192         #self.visM.run()
#     193         #self.visM.destroy_window()
# --> 194         self.visM.poll_events()
#     195         self.visM.update_renderer()
#     196         threading.Timer(0.1,self.execute()).start()
#
# KeyboardInterrupt:

# %%
print('a')

# %%
MD.visualize()

# %%
import threading
def p():
    print('a')
    threading.Timer(0.1,p).start()

# %%
p()

# %%
print('hello')
